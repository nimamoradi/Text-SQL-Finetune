# %%
import kagglehub
kagglehub.login()

# %%
path = kagglehub.model_download("google/gemma-3/transformers/gemma-3-270m-it")
# Out:
# ...
# 100%|██████████| 173/173 [00:00<00:00, 366kB/s]
# ...
# 100%|██████████| 35.0/35.0 [00:00<00:00, 44.4kB/s]
# ...
# 100%|██████████| 509/509 [00:00<00:00, 744kB/s]
# ...
# 100%|██████████| 1.32k/1.32k [00:00<00:00, 3.71MB/s]
# ...
# 100%|██████████| 1.50k/1.50k [00:00<00:00, 736kB/s]
# ...
#   0%|          | 0.00/4.47M [00:00<?, ?B/s]
# ...
#   0%|          | 0.00/511M [00:00<?, ?B/s]
#  22%|██▏       | 1.00M/4.47M [00:00<00:01, 2.79MB/s]
# ...
# 100%|██████████| 1.10M/1.10M [00:00<00:00, 380MB/s]A
#
#  45%|████▍     | 2.00M/4.47M [00:00<00:00, 3.31MB/s]
#
#   0%|          | 1.00M/511M [00:00<05:34, 1.60MB/s]
#  67%|██████▋   | 3.00M/4.47M [00:00<00:00, 3.96MB/s]
#  89%|████████▉ | 4.00M/4.47M [00:01<00:00, 4.25MB/s]
#
# 100%|██████████| 4.47M/4.47M [00:01<00:00, 3.99MB/s][A
#
#
#   1%|          | 3.00M/511M [00:01<04:04, 2.18MB/s]
#
#   1%|          | 4.00M/511M [00:01<03:52, 2.29MB/s]
#
#   1%|          | 5.00M/511M [00:02<03:29, 2.54MB/s]
#
#   1%|          | 6.00M/511M [00:02<03:05, 2.86MB/s]
#
# ...

# %%
import shutil
import os

print(f"Model downloaded to: {path}")
# Define our project destination
dest_dir = "./models/gemma-3-270m-it"
# Out:
# Model downloaded to: /Users/nima/.cache/kagglehub/models/google/gemma-3/transformers/gemma-3-270m-it/1
